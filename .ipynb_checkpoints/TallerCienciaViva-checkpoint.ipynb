# %% [markdown]
# # Taller Ciencia Viva 2024 - Departamento de Computación #
# ## Aprendizaje automático (Machine Learning) ##
#
# ### Objetivo: Hacer un clasificador de figuras en tiempo real.
#
# Durante este taller utilizaremos las siguientes bibliotecas:
#
# -  __[OpenCV](https://opencv.org/)__ : la utilizaremos para realizar el procesamiento de las imágenes
# -  __[scikit-learn](https://scikit-learn.org/stable/)__ : la utilizaremos para importar distintos algoritmos de aprendizaje supervisado y obtener herramientas para obtener métricas de nuestros resultados.
# -  __[numpy](https://numpy.org/)__ : la utilizaremos para realizar operaciones matriciales y la manipulación de las imágenes.
# -  __[matplotlib](https://matplotlib.org/)__ : la utilizaremos para realizar gráficas.
#
# Lo primero será importar las bibliotecas en nuestro nuestro script:

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
from sklearn import model_selection
from sklearn.model_selection import GridSearchCV
from sklearn.neural_network import MLPClassifier
from sklearn.decomposition import PCA
from sklearn import metrics
from IPython.display import display, Image
import ipywidgets as widgets
import threading
from PIL import Image

# %% [markdown]
# ## Procesamiento de imágenes
#
# ### Leer la imagen
#
# El primer paso es procesar la imágenes que ya obtuvieron con la cámara y vamos a leer en escala de grises con el siguiente comando:
#
# _Selecciona el parámetro correcto para leer la imagen en escala de grises._
# __[imread](https://www.geeksforgeeks.org/python-opencv-cv2-imread-method/)__
#
# *Nota: Deben cambiar la ubicación y el nombre con el que guardaron sus imágenes. :)*

# %%
nombre = "img/1.png"
parametro = cv2.IMREAD_GRAYSCALE
Img1 = cv2.imread( nombre, parametro )
rows, cols = Img1.shape
print("La imagen tiene {} filas y {} columnas".format(rows, cols))


print("Imagen en escala de grises")
display(Image.fromarray(Img1))
# Out:
# La imagen tiene 480 filas y 640 columnas
# Imagen en escala de grises
# <PIL.Image.Image image mode=L size=640x480>

# %% [markdown]
# ### Binarización de la imagen
# <a id="binarizar"></a>
# Ahora vamos binarizar la imagen, para eso es necesario buscar un umbral con el que las figuras de la imagen que leímos se ven completamente blancas.
#
# _Debes buscar cuáles son los mejores valores para los umbrales._

# %%
limInferior = 45
limSuperior = 255

ret,thresh1 = cv2.threshold(Img1,limInferior, limSuperior,cv2.THRESH_BINARY_INV)
print("Imagen binarizada")
display(Image.fromarray(thresh1))
# Out:
# Imagen binarizada
# <PIL.Image.Image image mode=L size=640x480>

# %% [markdown]
# ### Extracción de figuras de la imagen
# <a id="extraccion"></a>
# Ahora debemos extraer todas las figuras de nuestra imagen binarizada.
#
# _Debes verificar la carpeta en donde se van a guardar las imágenes._

# %%
n, Labels, stats, centroids = cv2.connectedComponentsWithStats( thresh1 )

print( "Se encontraron {} figuras".format(n) )
momentos = np.zeros((n-1, 7))

print("Los momentos de Hu de cada figura son los siguientes:")

i = 1
while i < n :
    #Se obtiene el perimetro
    x1 =  stats[i, cv2.CC_STAT_LEFT]
    y1 =  stats[i, cv2.CC_STAT_TOP]
    x2 = x1 + stats[i,cv2.CC_STAT_WIDTH]
    y2 = y1 + stats[i,cv2.CC_STAT_HEIGHT]
    #Se toman las esquinas de un rectangulo de la imagen binarizada y solo se analiza esa región
    Img2 = thresh1[y1:y2,x1:x2]
    mu = cv2.moments( Img2, True )
    hu = cv2.HuMoments(mu)
    momentos[i-1, :] = hu[:, 0]
    print("Figura {}".format(i))
    j=0
    while j < 7 :
        print( "{0:.05g}".format( hu[j,0] ), end=" " )
        j += 1
    print( )
        
    #display(Image.fromarray(Img2))
    #print(Img2)
    
    nombre = "I1/{0:02d}.png".format(i)
    cv2.imwrite( nombre, thresh1[y1:y2,x1:x2] )
    i += 1

np.savetxt("I1/momentosHu.txt", momentos, fmt='%1.7f')
# Out:
# Se encontraron 39 figuras
# Los momentos de Hu de cada figura son los siguientes:
# Figura 1
# 1.1973 1.4058 0.00017832 0.00016129 2.7353e-08 0.00018943 -2.476e-10
# Figura 2
# 0.3833 0.016547 9.1734e-06 1.6161e-06 -5.9328e-12 -1.9619e-07 1.8773e-12
# Figura 3
# 0.5049 0.004021 0.00017131 0.0005384 -1.6193e-07 -3.382e-05 2.2656e-08
# Figura 4
# 1.2681 1.5805 0.00036974 0.00030656 1.0317e-07 0.00036815 -2.9925e-09
# Figura 5
# 1.198 1.4024 0.020548 0.02079 0.0004297 0.024533 -3.4589e-07
# Figura 6
# 1.1608 1.3196 7.1163e-05 2.3056e-05 7.9835e-10 1.328e-05 4.8453e-10
# Figura 7
# 0.35157 0.00018295 4.3496e-05 1.5573e-06 2.7912e-12 1.7225e-08 1.2509e-11
# Figura 8
# 1.2394 1.5082 0.00012433 1.3822e-05 -5.6992e-10 -1.6933e-05 -5.9298e-11
# Figura 9
# 0.39123 0.014951 1.8498e-07 2.0427e-06 8.8153e-13 8.596e-08 -8.9425e-13
# Figura 10
# 0.45505 0.00095146 2.199e-06 2.0388e-06 -4.1696e-12 -5.3149e-08 -1.1184e-12
# Figura 11
# 1.3146 1.6999 3.621e-05 3.1794e-05 1.0786e-09 3.9853e-05 -1.9082e-11
# Figura 12
# 0.35081 0.00028707 8.4015e-05 1.7104e-06 1.823e-11 7.6765e-09 -9.3832e-12
# Figura 13
# 0.34874 0.0003262 1.6531e-05 4.0779e-07 2.1329e-13 5.401e-09 -1.0371e-12
# Figura 14
# 0.43905 0.047612 1.3862e-05 3.2231e-06 -7.176e-12 4.697e-08 -2.0314e-11
# Figura 15
# 1.1129 0.87172 0.10662 0.0018994 -2.6805e-05 0.0003194 3.472e-06
# Figura 16
# 0.38249 0.015851 7.3138e-06 3.1152e-06 1.468e-11 3.8872e-07 2.3671e-12
# Figura 17
# 0.34679 0.00023939 6.6102e-06 1.0638e-07 7.7004e-14 4.5221e-10 -4.5046e-14
# Figura 18
# 1.1188 0.70629 0.22414 0.0084571 -0.00030787 0.0023469 0.00020197
# Figura 19
# 0.39566 0.014211 3.4052e-06 1.9179e-05 1.3771e-10 2.1495e-06 -7.1115e-11
# Figura 20
# 1.3295 1.74 0.00017388 0.00016073 2.6869e-08 0.00021151 -1.0116e-10
# Figura 21
# 0.34784 0.00029379 9.7748e-05 1.0159e-05 3.0487e-10 -9.6608e-08 9.7736e-11
# Figura 22
# 0.3515 0.00026906 5.0873e-07 4.2474e-06 -5.8898e-12 -4.9789e-08 2.0719e-12
# Figura 23
# 1.1767 1.3569 0.00018792 0.00015717 2.7001e-08 0.0001756 -7.3381e-10
# Figura 24
# 0.4275 0.038073 5.0814e-06 8.1255e-07 -8.6488e-13 -5.5142e-08 -1.4064e-12
# Figura 25
# 0.35684 0.0005222 0.00016586 1.3861e-05 5.779e-10 -1.0029e-07 3.2823e-10
# Figura 26
# 0.35113 1.5858e-05 2.7405e-05 1.0463e-05 -1.1157e-10 -4.1606e-08 1.3764e-10
# Figura 27
# 0.45106 0.001104 2.9154e-06 2.3801e-05 1.8488e-10 -3.5281e-07 -7.1627e-11
# Figura 28
# 1.1781 1.3603 3.3664e-05 4.3455e-06 -2.4843e-11 -3.4324e-06 -4.6317e-11
# Figura 29
# 1.1597 1.317 0.00031301 0.00027967 8.2742e-08 0.00031791 8.2216e-10
# Figura 30
# 1.1589 0.89803 0.1577 0.0026623 -4.0839e-05 0.0013671 3.6165e-05
# Figura 31
# 0.36642 0.011498 4.8192e-07 3.21e-06 -3.9848e-12 3.2499e-07 -2.4667e-13
# Figura 32
# 1.1539 1.3038 0.00021738 0.00020118 4.2072e-08 0.00022807 2.5483e-10
# Figura 33
# 0.34272 0.00018505 8.4343e-05 4.6642e-06 -9.2431e-11 -6.3303e-08 3.8185e-12
# Figura 34
# 0.37471 0.01497 5.9285e-06 2.6789e-06 -1.0581e-11 -3.1855e-07 1.4147e-12
# Figura 35
# 0.34964 0.00043964 8.5429e-05 4.787e-07 2.7812e-12 6.7455e-09 -1.2791e-12
# Figura 36
# 1.1883 1.3842 0.00018086 0.00016696 2.9012e-08 0.00019638 3.024e-11
# Figura 37
# 0.33691 0.00037819 5.2209e-05 2.7151e-06 -2.2721e-12 2.7737e-08 -3.2246e-11
# Figura 38
# 0.41651 0.033866 5.1473e-06 9.3144e-06 6.4415e-11 1.5896e-06 -3.2083e-12

# %% [markdown]
# ### Rotar imágenes
# Una vez que termines deberás realizar lo siguiente:
# -  Debes regresar a la sección de [binarización](#binarizar) y debes rotar la imagen 2 veces (-90 y 90), antes de realizar la binarización de la imagen. __[Función para rotar la imgen](https://www.geeksforgeeks.org/python-opencv-cv2-rotate-method/)__
#
# ### Etiquetar los datos obtenidos
# -  Una vez termines de rotar las imagenes, deberás tener 3 carpetas (con el nombre que hayas decidido) con todas las imágenes de las figuras que extrajiste y también 3 archivos donde están guardados los momentos de Hu.
# - Deben abrir la carpeta donde estén todas las imágenes:
# ![Figuras.png](attachment:f8fdcacd-d9ee-4d9d-b1e2-05e5fffea653.png)
# - Y también deben abrir el archivo en donde se guardaron los momentos de Hu:
# ![MomentosHu.png](attachment:08a3bd60-1dc4-4ed6-b2b9-bdf913d73739.png)
# - Ahora vamos a asignarle a cada figura una etiqueta, por ejemplo en la imagen vemos que hay cuatro figuras, una línea, una cruz, un círculo y una elipse. Por lo tanto podemos asignarle las siguientes etiquetas linea = 0, cruz = 1, circulo = 2 y elipse = 3. Una vez hecho esto vamos a agregar una columna más, al archivo donde se encuentran los momentos, estos se encuentran guardados en el orden que se fueron encontrando las figuras, es decir la figura 01 corresponde al primer renglón del archivo y así sucesivamente. El archivo final se verá de la siguiente forma, te recomiendo renombrarlo como Datos.txt:
# ![Etiquetado.png](attachment:5780fd91-e30c-41f9-8c8f-c9fd520efe00.png)
# - Este proceso de etiquetado lo van a realizar para las 3 carpetas con imágenes que se generaron después de las rotaciones y la extracción de características. [Extracción](#extraccion)

# %% [markdown]
# ## Generación de los conjuntos de entrenamiento y prueba
#
# Para este punto debes tener 1 archivo de datos en cada carpeta, en total serán 3. Con estos datos vamos a crear nuestros conjuntos de entrenamiento.

# %%
Direccion1 = "I1/Datos.txt"
Direccion2 = "I2/Datos.txt"
Direccion3 = "I3/Datos.txt" 

Datos1 = np.loadtxt(Direccion1)
print("El conjunto de datos número 1 tiene {}".format(Datos1.shape[0]))

Datos2 = np.loadtxt(Direccion2)
print("El conjunto de datos número 2 tiene {}".format(Datos2.shape[0]))

Datos3 = np.loadtxt(Direccion3)
print("El conjunto de datos número 3 tiene {}".format(Datos3.shape[0]))

print(Datos2.shape)
print(Datos1.shape)

tmp = np.vstack((Datos1, Datos2))
tmp = np.vstack((tmp, Datos3))

Xtodo = tmp[:, 0:7]
ytodo = tmp[:, 7]



Xentrena, Xprueba, yentrena, yprueba = model_selection.train_test_split( Xtodo, ytodo, test_size = 0.2, random_state = 42 )
print("Este es el tamaño de el conjunto de entrenamiento: ")
print(Xentrena.shape)
print("Este es el tamaño de el conjunto de prueba: ")
print(Xprueba.shape)

np.savetxt("Datos/EntrenamientoX.txt", Xentrena, fmt='%1.7f')
np.savetxt("Datos/EntrenamientoY.txt", yentrena, fmt='%1.7f')
np.savetxt("Datos/PruebaX.txt", Xprueba, fmt='%1.7f')
np.savetxt("Datos/PruebaY.txt", yprueba, fmt='%1.7f')
# Out:
# El conjunto de datos número 1 tiene 38
# El conjunto de datos número 2 tiene 34
# El conjunto de datos número 3 tiene 34
# (34, 8)
# (38, 8)
# Este es el tamaño de el conjunto de entrenamiento:
# (84, 7)
# Este es el tamaño de el conjunto de prueba:
# (22, 7)

# %% [markdown]
# ## Reducción de dimensionalidad

# %%
pca = PCA(n_components=3)
n = pca.fit_transform(Xentrena)
print(n.shape)

fig = plt.figure()
ax = plt.axes(projection = "3d")
ax.scatter3D(n[:,0], n[:,1], n[:,2], c=yentrena)
plt.show()
# Out:
# (84, 3)

# %%
pca = PCA(n_components=2)
n = pca.fit_transform(Xentrena)
print(n.shape)

fig = plt.figure()
ax = plt.axes()
ax.scatter(n[:,0], n[:,1], c=yentrena)
plt.show()
# Out:
# (84, 2)

# %% [markdown]
# ## Entrenamiento de una Red Neuronal
# Aquí vas elegir los parámetros de forma manual para entrenar tu clasificador utilizando una red neuronal. Esto suele ser una tarea complicada, ya que a veces no es sencillo encontrar los mejores parámetros, porque no puedes predecir que efecto tendrá en toda la red ese cambio, puedes mejorar o empeorar completamente el resuldado.
#
# Pero vamos a intentarlo, tal vez los encuentres de forma manual, los parámetros que puedes modificar son los siguientes:
#
# - El parámetro *capas*, te va a permitir seleccionar cuantas capas ocultas y el tamaño de estas, no existe una regla para seleccionarlas, pero puedes probar incementando, cuida que la red no sea muy grande recuerda que son operaciones matriciales.
# - El parámetro *semilla*, te va a permitir controlar como se inicializan los pesos dentro de la red.
# - El parámetro *activacion*
#
# La meta es obetener al menos 0.90 o más en la exactitud de las pruebas.

# %%
capas = (100,4)
semilla = 8
# relu, tanh
activacion = 'tanh'
red = MLPClassifier(hidden_layer_sizes=capas, random_state=semilla, max_iter=10000)
print(red)
print("Entrenando la red ... ")
red.fit(Xentrena, yentrena)

ypredichas = red.predict(Xentrena)
exactitud = metrics.accuracy_score(yentrena, ypredichas)
print("La exactitud del entrenamiento es {}".format(exactitud))

ypredichas = red.predict(Xprueba)
exactitud = metrics.accuracy_score(yprueba, ypredichas)
print("La exactitud de la pruebas es {}".format(exactitud))
# Out:
# MLPClassifier(hidden_layer_sizes=(100, 4), max_iter=10000, random_state=8)
# Entrenando la red ...
# La exactitud del entrenamiento es 0.9047619047619048
# La exactitud de la pruebas es 0.8636363636363636

# %% [markdown]
# ### Búsqueda en malla para sintonizar los parámetros de la red
#
# La búsqueda en malla nos va permitir que de una forma sistematica se prueben diferentes combinaciones de parámetros y se obtendrán las estadísticas para seleccionar cuál es la mejor opción, para este problema en especifico.
#
# El problema con esta técnica es que es difícil abarcar todas las posibles combinaciones, funciona bien si se tiene en mente exactamente bajo que criterios se quiere optimizar la red. Cuando no se tiene tan acotado el problema se pueden utilizar otro tipo de técnicas donde se busca también la mejor arquitectura y la optimización de los pesos.
#
# *Van a salir unas advertencias de convergencia, no hay de que asustarse. :)*

# %%
parameter_space = {
    'hidden_layer_sizes': [(16,8),(10,4), (8, 4)],
    'activation': ['tanh', 'relu', 'logistic'],
    'random_state': [0,1 ,2, 3, 4],
    'solver': ['sgd', 'adam', 'lbfgs'],
    'alpha': [0.0001, 0.05],
    'learning_rate': ['constant','adaptive'],
}

red_malla = MLPClassifier(max_iter=10000000)
clf = GridSearchCV(red_malla, parameter_space, n_jobs=-1, cv=5)
clf.fit(Xentrena, yentrena)
print("Los mejores parámetros para esta red son los siguientes: {}".format(clf.best_params_))
# Out:
# Los mejores parámetros para esta red son los siguientes: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'lbfgs'}

# %%
print(" Aquí podemos ver las estadísticas de todas las combinaciones:  \n")

means = clf.cv_results_['mean_test_score']
stds = clf.cv_results_['std_test_score']
#Se va imprimir el promedio y la desviación estandar
for mean, std, params in zip(means, stds, clf.cv_results_['params']):
    print("%0.3f (+/-%0.03f) para %r" % (mean, std * 2, params))
# Out:
#  Aquí podemos ver las estadísticas de todas las combinaciones:
#
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'sgd'}
# 0.859 (+/-0.346) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 1, 'solver': 'sgd'}
# 0.988 (+/-0.047) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 1, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 1, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 2, 'solver': 'sgd'}
# 0.988 (+/-0.047) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 2, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 2, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 3, 'solver': 'sgd'}
# 0.988 (+/-0.047) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 3, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 3, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 4, 'solver': 'sgd'}
# 0.785 (+/-0.307) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 4, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 4, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'sgd'}
# 0.859 (+/-0.346) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 1, 'solver': 'sgd'}
# 0.988 (+/-0.047) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 1, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 1, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 2, 'solver': 'sgd'}
# 0.988 (+/-0.047) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 2, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 2, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 3, 'solver': 'sgd'}
# 0.988 (+/-0.047) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 3, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 3, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 4, 'solver': 'sgd'}
# 0.785 (+/-0.307) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 4, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 4, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'constant', 'random_state': 1, 'solver': 'sgd'}
# 0.976 (+/-0.059) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'constant', 'random_state': 1, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'constant', 'random_state': 1, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'constant', 'random_state': 2, 'solver': 'sgd'}
# 0.846 (+/-0.329) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'constant', 'random_state': 2, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'constant', 'random_state': 2, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'constant', 'random_state': 3, 'solver': 'sgd'}
# 0.963 (+/-0.099) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'constant', 'random_state': 3, 'solver': 'adam'}
# 0.976 (+/-0.058) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'constant', 'random_state': 3, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'constant', 'random_state': 4, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'constant', 'random_state': 4, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'constant', 'random_state': 4, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'adaptive', 'random_state': 1, 'solver': 'sgd'}
# 0.976 (+/-0.059) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'adaptive', 'random_state': 1, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'adaptive', 'random_state': 1, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'adaptive', 'random_state': 2, 'solver': 'sgd'}
# 0.846 (+/-0.329) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'adaptive', 'random_state': 2, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'adaptive', 'random_state': 2, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'adaptive', 'random_state': 3, 'solver': 'sgd'}
# 0.963 (+/-0.099) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'adaptive', 'random_state': 3, 'solver': 'adam'}
# 0.976 (+/-0.058) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'adaptive', 'random_state': 3, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'adaptive', 'random_state': 4, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'adaptive', 'random_state': 4, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'adaptive', 'random_state': 4, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'random_state': 1, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'random_state': 1, 'solver': 'adam'}
# 0.988 (+/-0.047) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'random_state': 1, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'random_state': 2, 'solver': 'sgd'}
# 0.988 (+/-0.050) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'random_state': 2, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'random_state': 2, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'random_state': 3, 'solver': 'sgd'}
# 0.775 (+/-0.213) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'random_state': 3, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'random_state': 3, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'random_state': 4, 'solver': 'sgd'}
# 0.857 (+/-0.055) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'random_state': 4, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'random_state': 4, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 1, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 1, 'solver': 'adam'}
# 0.988 (+/-0.047) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 1, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 2, 'solver': 'sgd'}
# 0.988 (+/-0.050) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 2, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 2, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 3, 'solver': 'sgd'}
# 0.775 (+/-0.213) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 3, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 3, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 4, 'solver': 'sgd'}
# 0.857 (+/-0.055) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 4, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 4, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'sgd'}
# 0.738 (+/-0.194) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 1, 'solver': 'sgd'}
# 0.988 (+/-0.047) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 1, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 1, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 2, 'solver': 'sgd'}
# 0.988 (+/-0.047) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 2, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 2, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 3, 'solver': 'sgd'}
# 0.976 (+/-0.059) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 3, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 3, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 4, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 4, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 4, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'sgd'}
# 0.738 (+/-0.194) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 1, 'solver': 'sgd'}
# 0.988 (+/-0.047) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 1, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 1, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 2, 'solver': 'sgd'}
# 0.988 (+/-0.047) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 2, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 2, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 3, 'solver': 'sgd'}
# 0.976 (+/-0.059) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 3, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 3, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 4, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 4, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 4, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'constant', 'random_state': 1, 'solver': 'sgd'}
# 0.857 (+/-0.055) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'constant', 'random_state': 1, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'constant', 'random_state': 1, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'constant', 'random_state': 2, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'constant', 'random_state': 2, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'constant', 'random_state': 2, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'constant', 'random_state': 3, 'solver': 'sgd'}
# 0.857 (+/-0.055) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'constant', 'random_state': 3, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'constant', 'random_state': 3, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'constant', 'random_state': 4, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'constant', 'random_state': 4, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'constant', 'random_state': 4, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'adaptive', 'random_state': 1, 'solver': 'sgd'}
# 0.857 (+/-0.055) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'adaptive', 'random_state': 1, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'adaptive', 'random_state': 1, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'adaptive', 'random_state': 2, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'adaptive', 'random_state': 2, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'adaptive', 'random_state': 2, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'adaptive', 'random_state': 3, 'solver': 'sgd'}
# 0.857 (+/-0.055) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'adaptive', 'random_state': 3, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'adaptive', 'random_state': 3, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'adaptive', 'random_state': 4, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'adaptive', 'random_state': 4, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'adaptive', 'random_state': 4, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'random_state': 1, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'random_state': 1, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'random_state': 1, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'random_state': 2, 'solver': 'sgd'}
# 0.870 (+/-0.086) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'random_state': 2, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'random_state': 2, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'random_state': 3, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'random_state': 3, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'random_state': 3, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'random_state': 4, 'solver': 'sgd'}
# 0.857 (+/-0.055) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'random_state': 4, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'random_state': 4, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 1, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 1, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 1, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 2, 'solver': 'sgd'}
# 0.870 (+/-0.086) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 2, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 2, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 3, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 3, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 3, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 4, 'solver': 'sgd'}
# 0.857 (+/-0.055) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 4, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 4, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 1, 'solver': 'sgd'}
# 1.000 (+/-0.000) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 1, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 1, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 2, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 2, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 2, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 3, 'solver': 'sgd'}
# 0.869 (+/-0.087) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 3, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 3, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 4, 'solver': 'sgd'}
# 0.859 (+/-0.346) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 4, 'solver': 'adam'}
# 0.893 (+/-0.049) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 4, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 1, 'solver': 'sgd'}
# 1.000 (+/-0.000) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 1, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 1, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 2, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 2, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 2, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 3, 'solver': 'sgd'}
# 0.869 (+/-0.087) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 3, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 3, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 4, 'solver': 'sgd'}
# 0.859 (+/-0.346) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 4, 'solver': 'adam'}
# 0.893 (+/-0.049) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 4, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'adam'}
# 0.976 (+/-0.059) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'lbfgs'}
# 0.381 (+/-0.053) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'constant', 'random_state': 1, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'constant', 'random_state': 1, 'solver': 'adam'}
# 0.381 (+/-0.053) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'constant', 'random_state': 1, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'constant', 'random_state': 2, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'constant', 'random_state': 2, 'solver': 'adam'}
# 0.976 (+/-0.094) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'constant', 'random_state': 2, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'constant', 'random_state': 3, 'solver': 'sgd'}
# 0.763 (+/-0.193) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'constant', 'random_state': 3, 'solver': 'adam'}
# 0.929 (+/-0.115) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'constant', 'random_state': 3, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'constant', 'random_state': 4, 'solver': 'sgd'}
# 0.904 (+/-0.060) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'constant', 'random_state': 4, 'solver': 'adam'}
# 0.916 (+/-0.143) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'constant', 'random_state': 4, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'adam'}
# 0.976 (+/-0.059) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'lbfgs'}
# 0.381 (+/-0.053) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'adaptive', 'random_state': 1, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'adaptive', 'random_state': 1, 'solver': 'adam'}
# 0.381 (+/-0.053) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'adaptive', 'random_state': 1, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'adaptive', 'random_state': 2, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'adaptive', 'random_state': 2, 'solver': 'adam'}
# 0.976 (+/-0.094) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'adaptive', 'random_state': 2, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'adaptive', 'random_state': 3, 'solver': 'sgd'}
# 0.763 (+/-0.193) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'adaptive', 'random_state': 3, 'solver': 'adam'}
# 0.929 (+/-0.115) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'adaptive', 'random_state': 3, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'adaptive', 'random_state': 4, 'solver': 'sgd'}
# 0.904 (+/-0.060) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'adaptive', 'random_state': 4, 'solver': 'adam'}
# 0.916 (+/-0.143) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'adaptive', 'random_state': 4, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'adam'}
# 0.988 (+/-0.050) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'lbfgs'}
# 0.620 (+/-0.270) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'random_state': 1, 'solver': 'sgd'}
# 0.893 (+/-0.087) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'random_state': 1, 'solver': 'adam'}
# 0.812 (+/-0.467) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'random_state': 1, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'random_state': 2, 'solver': 'sgd'}
# 0.810 (+/-0.281) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'random_state': 2, 'solver': 'adam'}
# 0.965 (+/-0.141) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'random_state': 2, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'random_state': 3, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'random_state': 3, 'solver': 'adam'}
# 0.892 (+/-0.192) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'random_state': 3, 'solver': 'lbfgs'}
# 0.298 (+/-0.015) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'random_state': 4, 'solver': 'sgd'}
# 0.298 (+/-0.015) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'random_state': 4, 'solver': 'adam'}
# 0.381 (+/-0.053) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'random_state': 4, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'adam'}
# 0.988 (+/-0.050) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'lbfgs'}
# 0.620 (+/-0.270) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 1, 'solver': 'sgd'}
# 0.893 (+/-0.087) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 1, 'solver': 'adam'}
# 0.812 (+/-0.467) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 1, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 2, 'solver': 'sgd'}
# 0.810 (+/-0.281) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 2, 'solver': 'adam'}
# 0.965 (+/-0.141) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 2, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 3, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 3, 'solver': 'adam'}
# 0.892 (+/-0.192) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 3, 'solver': 'lbfgs'}
# 0.298 (+/-0.015) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 4, 'solver': 'sgd'}
# 0.298 (+/-0.015) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 4, 'solver': 'adam'}
# 0.381 (+/-0.053) para {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 4, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 1, 'solver': 'sgd'}
# 0.940 (+/-0.129) para {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 1, 'solver': 'adam'}
# 0.951 (+/-0.119) para {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 1, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 2, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 2, 'solver': 'adam'}
# 0.964 (+/-0.059) para {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 2, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 3, 'solver': 'sgd'}
# 0.857 (+/-0.055) para {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 3, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 3, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 4, 'solver': 'sgd'}
# 0.785 (+/-0.307) para {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 4, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 4, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 1, 'solver': 'sgd'}
# 0.940 (+/-0.129) para {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 1, 'solver': 'adam'}
# 0.951 (+/-0.119) para {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 1, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 2, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 2, 'solver': 'adam'}
# 0.964 (+/-0.059) para {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 2, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 3, 'solver': 'sgd'}
# 0.857 (+/-0.055) para {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 3, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 3, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 4, 'solver': 'sgd'}
# 0.785 (+/-0.307) para {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 4, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 4, 'solver': 'lbfgs'}
# 0.679 (+/-0.053) para {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'lbfgs'}
# ...
# 0.381 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 2, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 2, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 2, 'solver': 'lbfgs'}
# 0.381 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 3, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 3, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 3, 'solver': 'lbfgs'}
# 0.381 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 4, 'solver': 'sgd'}
# 0.381 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 4, 'solver': 'adam'}
# 1.000 (+/-0.000) para {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 4, 'solver': 'lbfgs'}
# 0.381 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'adam'}
# 0.869 (+/-0.046) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'lbfgs'}
# 0.381 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 1, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 1, 'solver': 'adam'}
# 0.857 (+/-0.055) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 1, 'solver': 'lbfgs'}
# 0.381 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 2, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 2, 'solver': 'adam'}
# 0.857 (+/-0.055) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 2, 'solver': 'lbfgs'}
# 0.381 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 3, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 3, 'solver': 'adam'}
# 0.857 (+/-0.055) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 3, 'solver': 'lbfgs'}
# 0.381 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 4, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 4, 'solver': 'adam'}
# 0.857 (+/-0.055) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'constant', 'random_state': 4, 'solver': 'lbfgs'}
# 0.381 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'adam'}
# 0.869 (+/-0.046) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'lbfgs'}
# 0.381 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 1, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 1, 'solver': 'adam'}
# 0.857 (+/-0.055) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 1, 'solver': 'lbfgs'}
# 0.381 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 2, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 2, 'solver': 'adam'}
# 0.857 (+/-0.055) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 2, 'solver': 'lbfgs'}
# 0.381 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 3, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 3, 'solver': 'adam'}
# 0.857 (+/-0.055) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 3, 'solver': 'lbfgs'}
# 0.381 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 4, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 4, 'solver': 'adam'}
# 0.857 (+/-0.055) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (16, 8), 'learning_rate': 'adaptive', 'random_state': 4, 'solver': 'lbfgs'}
# 0.381 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'adam'}
# 0.857 (+/-0.055) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'lbfgs'}
# 0.381 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'constant', 'random_state': 1, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'constant', 'random_state': 1, 'solver': 'adam'}
# 0.857 (+/-0.055) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'constant', 'random_state': 1, 'solver': 'lbfgs'}
# 0.381 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'constant', 'random_state': 2, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'constant', 'random_state': 2, 'solver': 'adam'}
# 0.857 (+/-0.055) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'constant', 'random_state': 2, 'solver': 'lbfgs'}
# 0.381 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'constant', 'random_state': 3, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'constant', 'random_state': 3, 'solver': 'adam'}
# 0.857 (+/-0.055) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'constant', 'random_state': 3, 'solver': 'lbfgs'}
# 0.381 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'constant', 'random_state': 4, 'solver': 'sgd'}
# 0.381 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'constant', 'random_state': 4, 'solver': 'adam'}
# 0.857 (+/-0.055) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'constant', 'random_state': 4, 'solver': 'lbfgs'}
# 0.381 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'adam'}
# 0.857 (+/-0.055) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'lbfgs'}
# 0.381 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'adaptive', 'random_state': 1, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'adaptive', 'random_state': 1, 'solver': 'adam'}
# 0.857 (+/-0.055) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'adaptive', 'random_state': 1, 'solver': 'lbfgs'}
# 0.381 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'adaptive', 'random_state': 2, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'adaptive', 'random_state': 2, 'solver': 'adam'}
# 0.857 (+/-0.055) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'adaptive', 'random_state': 2, 'solver': 'lbfgs'}
# 0.381 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'adaptive', 'random_state': 3, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'adaptive', 'random_state': 3, 'solver': 'adam'}
# 0.857 (+/-0.055) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'adaptive', 'random_state': 3, 'solver': 'lbfgs'}
# 0.381 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'adaptive', 'random_state': 4, 'solver': 'sgd'}
# 0.381 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'adaptive', 'random_state': 4, 'solver': 'adam'}
# 0.857 (+/-0.055) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (10, 4), 'learning_rate': 'adaptive', 'random_state': 4, 'solver': 'lbfgs'}
# 0.381 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'adam'}
# 0.857 (+/-0.055) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'lbfgs'}
# 0.381 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'random_state': 1, 'solver': 'sgd'}
# 0.381 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'random_state': 1, 'solver': 'adam'}
# 0.857 (+/-0.055) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'random_state': 1, 'solver': 'lbfgs'}
# 0.381 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'random_state': 2, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'random_state': 2, 'solver': 'adam'}
# 0.857 (+/-0.055) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'random_state': 2, 'solver': 'lbfgs'}
# 0.381 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'random_state': 3, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'random_state': 3, 'solver': 'adam'}
# 0.857 (+/-0.055) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'random_state': 3, 'solver': 'lbfgs'}
# 0.381 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'random_state': 4, 'solver': 'sgd'}
# 0.381 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'random_state': 4, 'solver': 'adam'}
# 0.857 (+/-0.055) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'constant', 'random_state': 4, 'solver': 'lbfgs'}
# 0.381 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'adam'}
# 0.857 (+/-0.055) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'lbfgs'}
# 0.381 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 1, 'solver': 'sgd'}
# 0.381 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 1, 'solver': 'adam'}
# 0.857 (+/-0.055) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 1, 'solver': 'lbfgs'}
# 0.381 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 2, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 2, 'solver': 'adam'}
# 0.857 (+/-0.055) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 2, 'solver': 'lbfgs'}
# 0.381 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 3, 'solver': 'sgd'}
# 0.679 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 3, 'solver': 'adam'}
# 0.857 (+/-0.055) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 3, 'solver': 'lbfgs'}
# 0.381 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 4, 'solver': 'sgd'}
# 0.381 (+/-0.053) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 4, 'solver': 'adam'}
# 0.857 (+/-0.055) para {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (8, 4), 'learning_rate': 'adaptive', 'random_state': 4, 'solver': 'lbfgs'}

# %%
print("Entrenando la red con los mejores parámetros encontrados... ")

activacion = clf.best_params_['activation']
capas = clf.best_params_['hidden_layer_sizes']
semilla = clf.best_params_['random_state']
alfa = clf.best_params_['alpha']
tasa = clf.best_params_['learning_rate']
entrenamiento = clf.best_params_['solver']

red_optimizada = MLPClassifier(hidden_layer_sizes= capas, 
                               random_state= semilla,
                               solver = entrenamiento, 
                               alpha = alfa,
                               learning_rate = tasa,
                               activation = activacion,
                               max_iter=10000)
red_optimizada.fit(Xentrena, yentrena)

ypredichas = red_optimizada.predict(Xprueba)
exactitud = metrics.accuracy_score(yprueba, ypredichas)
print("La exactitud de la pruebas es {}".format(exactitud))
# Out:
# Entrenando la red con los mejores parámetros encontrados...
# La exactitud de la pruebas es 1.0

# %% [markdown]
# Extracción de coeficientes para guardar el modelo:

# %%
capas_ocultas = len(red_optimizada.coefs_)
for i in range(capas_ocultas):
    print("Capa {} ".format((i+1)))
    print("Tamaño: {}".format(red_optimizada.coefs_[i].shape))
    print("Pesos: \n{} ".format(red_optimizada.coefs_[i]))
    print("Sesgos: {}".format(red_optimizada.intercepts_[i]))
# Out:
# Capa 1
# Tamaño: (7, 16)
# Pesos:
# [[-1.13423117  4.15677496  3.26777881  1.43462008 -0.75401136 -1.77905903
#   -3.44214526  1.80853061 -2.50058399 -0.4934496  -0.80820484  0.38374617
#    0.58382835 -1.79667795 -1.28594391 -1.14253787]
#  [-3.42178777  2.67378537  0.96450445  2.98962059  0.51390002  9.6112323
#   -2.24231489  1.90880973 -2.19116039  0.34498736 -3.5478348  -0.18566613
#   -2.28525189 -2.56658292  0.62478039 -0.58479256]
#  [-0.01357782  0.05168787 -0.47157807  0.09324173  0.10920713  0.065971
#    0.43539911  0.17548582 -0.13545839 -0.06060596  0.19365998 -0.42880314
#    0.16211937  0.16678069 -0.28251906 -0.36193099]
#  [-0.17988433 -0.13304688  0.06883388 -0.06011947  0.47643132 -0.38983355
#   -0.28423917 -0.33072079  0.14925197 -0.24070574 -0.03287557 -0.24903533
#   -0.33280123 -0.37992653  0.15235197 -0.35296223]
#  [-0.2960192  -0.12807388  0.31316626 -0.39307456  0.32970457 -0.39405296
#    0.4648416  -0.03058439  0.46513589  0.10228902  0.23342934 -0.44957591
#   -0.21189714 -0.37054241 -0.19888896 -0.37197548]
#  [-0.177569   -0.08365587 -0.4251429   0.18785057  0.06496826 -0.22872854
#    0.02253868 -0.39613164  0.07401034  0.41888407 -0.17734381  0.16335132
#   -0.35944545  0.21114197 -0.20546194 -0.30914304]
#  [ 0.08440344 -0.46819092  0.32091927 -0.48322719  0.17348072 -0.22438398
#    0.22945913  0.4509187  -0.24512054  0.07430034  0.08979759  0.07049014
#   -0.27016609  0.44170933 -0.05158534  0.33796196]]
# Sesgos: [ 3.62008111 -2.09333553 -0.24074065  1.21213486 -1.80043727  0.55627927
#   0.939221    3.62540574  1.51703888  2.9557997   2.27114911 -3.31998372
#   1.71091367 -3.91122655 -2.56105412 -2.69503418]
# Capa 2
# Tamaño: (16, 8)
# Pesos:
# [[-2.36186348  2.6521258   1.35705355 -0.99308369 -0.86804756  0.52051333
#   -0.29317972 -1.34528949]
#  [ 3.36379441 -1.96589401 -1.99876055  0.31394788  1.91676281 -0.52064525
#    0.83401828  2.55890312]
#  [ 0.76915124 -0.50975191 -1.39126854  0.12255071  1.37407271 -0.17265545
#    0.2906309   0.82743378]
#  [ 0.78783962 -2.26220635 -2.25662371  0.59925807  2.4167236  -0.82445124
#    0.80653112  2.51314438]
#  [ 0.55284376  1.68324233  0.07595185  0.22238806 -0.41440273 -0.74318393
#   -0.63822819 -1.17290527]
#  [10.31401241 -1.58334533 -2.31688219 -0.58268154  0.65693945 -1.2778798
#    1.02657908 -2.01285427]
#  [-0.59913167  2.93220369  1.73324145 -1.23919707 -3.89213463  0.48043324
#   -1.05886501 -1.91942669]
#  [ 1.32039826 -0.45543763 -1.49089066 -0.85130399  1.70200026 -0.73760953
#    0.9046388   0.52440149]
#  [-1.14478166  3.28995064  0.49358667 -1.3766482  -1.26757411  0.72356092
#   -0.6525207  -0.3774805 ]
#  [ 1.36395592 -1.36042933 -0.18816443 -0.46889582 -0.41351795 -0.91332365
#    0.32466572  0.17898318]
#  [-2.15591611  3.26790605  1.54502644 -1.39618053 -3.32816061  1.17016765
#   -1.706292   -2.79358223]
#  [-0.09507366  0.78591799 -0.63326951  0.87695682  0.58774643 -0.48399777
#    0.03140354  0.2763852 ]
#  [-0.32512661  0.90181553  0.50699006 -0.2299177  -1.51192978  0.89704548
#   -1.00857429 -0.49824305]
#  [-0.68111927  0.66447473 -1.70136057 -0.74935642  3.0094335  -0.14081377
#    1.0434801   1.78886555]
#  [-0.35223752 -0.70093224  1.1582814   1.19506402 -0.65509948  0.38989014
#   -0.66183255 -0.80266792]
#  [-0.7113659  -0.38645037  0.80021702  1.79727555 -0.79783637 -0.02577008
#   -0.35503664 -1.68181616]]
# Sesgos: [ 1.94677982  3.22337615  0.63863887 -3.19230934 -2.55022506 -1.17162372
#  -0.64825815 -0.65155566]
# Capa 3
# Tamaño: (8, 4)
# Pesos:
# [[ 2.13591913e+00  1.12551990e+01 -5.67133417e+00 -7.28323112e+00]
#  [-3.75146750e+00  4.37787998e+00  2.05348132e+00 -2.13478212e+00]
#  [-6.78376568e+00 -2.57351425e-01 -1.42323352e+00  9.11368928e+00]
#  [ 5.24742644e+00 -7.63534377e-01 -1.60456475e+00 -1.19730407e+00]
#  [ 4.84945211e+00 -3.26077114e+00 -1.97014149e+00  7.49607683e-02]
#  [ 1.05835403e-01  6.20942679e-01 -1.38115723e+00  5.94373960e-01]
#  [ 7.88608016e-01 -7.64173806e-01 -1.48304957e+00  9.75543104e-01]
#  [ 1.34113709e+00 -1.03594166e-02  5.55937430e+00 -7.23106128e+00]]
# Sesgos: [-0.51559549  0.70987823  0.29051637  0.77921103]

# %% [markdown]
# ### Prueba del modelo
#
# Vamos a cargar una imagen con la que no se entreno el modelo y vamos a clasificar las figuras que están en la imgen y vamos pintar en la imagen dependiendo la figura con diferentes colores.

# %%
nombre = "FotoPrueba/Prueba1.png"

font = cv2.FONT_HERSHEY_SIMPLEX
org = (50, 50)
fontScale = 0.5

thickness = 2

ImgColor = cv2.imread( nombre)
Img1 = cv2.imread( nombre, cv2.IMREAD_GRAYSCALE )

limInferior = 45
limSuperior = 255

ret,thresh1 = cv2.threshold(Img1,limInferior, limSuperior,cv2.THRESH_BINARY_INV)

n, Labels, stats, centroids = cv2.connectedComponentsWithStats( thresh1 )
i = 1
while i < n :
    #Se obtiene el perimetro
    x1 =  stats[i, cv2.CC_STAT_LEFT]
    y1 =  stats[i, cv2.CC_STAT_TOP]
    x2 = x1 + stats[i,cv2.CC_STAT_WIDTH]
    y2 = y1 + stats[i,cv2.CC_STAT_HEIGHT]
    #Se toman las esquinas de un rectangulo de la imagen binarizada y solo se analiza esa región
    Img2 = thresh1[y1:y2,x1:x2]
    mu = cv2.moments( Img2, True )
    hu = cv2.HuMoments(mu)
    #print(hu.shape)
    #print(hu.T)
    ypredicha = red_optimizada.predict(hu.T)
    
    if(ypredicha == 0):
        color = (255, 0, 0)
        MCor = cv2.putText(ImgColor, '0', (x1+5,y1+5), font, fontScale, color, thickness, cv2.LINE_AA) 
    if(ypredicha == 1):
        color = (0, 255, 0)
        MCor = cv2.putText(ImgColor, '1', (x1+5,y1+5), font, fontScale, color, thickness, cv2.LINE_AA)
    if(ypredicha == 2):
        color = (0, 0, 255)
        MCor = cv2.putText(ImgColor, '2', (x1+5,y1+5), font, fontScale, color, thickness, cv2.LINE_AA)
    if(ypredicha == 3):
        color = (255, 0, 255)
        MCor = cv2.putText(ImgColor, '3', (x1+5,y1+5), font, fontScale, color, thickness, cv2.LINE_AA)
    start_point = (x1, y1)
    end_point = (x2, y2)
            
    thickness = 2
    MCor = cv2.rectangle(ImgColor, start_point, end_point, color, thickness)
    i = i + 1

display(Image.fromarray(MCor))
# Out:
# <PIL.Image.Image image mode=RGB size=640x480>
